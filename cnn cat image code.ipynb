# %%
import skimage.data
import numpy
import sys

# %%
img=skimage.data.chelsea()
print(img.shape)
img=skimage.color.rgb2gray(img)
# Out:
# (300, 451, 3)

# %%
skimage.io.imshow(img)

# %%
img.shape
# Out:
# (300, 451)

# %%
number_of_filters=10
filter_dimensions=10
l1_filter=numpy.random.random((number_of_filters, filter_dimensions, filter_dimensions))

# %%
def my_conv(img, conv_filter):
    filter_num=conv_filter.shape[0]
    filter_size=conv_filter.shape[1]
    feature_map=numpy.zeros((img.shape[0]-filter_size+1, img.shape[1]-filter_size+1, filter_num))
    for i in range(filter_num):
        print("Filter number: "+str(i+1))
        conv_filter_mul=conv_filter[i,:,:]
        
    for r in range(0, img.shape[0]-filter_size+1):
        for c in range(0, img.shape[1]-filter_size+1):
            center_pix=numpy.sum(img[r:(r+filter_size), c:(c+filter_size)]*conv_filter_mul)
            feature_map[r,c,i]=center_pix
            
    return feature_map

# %%
l1_feature_map=my_conv(img, l1_filter)
# Out:
# Filter number: 1
# Filter number: 2
# Filter number: 3
# Filter number: 4
# Filter number: 5
# Filter number: 6
# Filter number: 7
# Filter number: 8
# Filter number: 9
# Filter number: 10

# %%
l1_feature_map[0]
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 27.01261735],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 26.85677053],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 26.73178431],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  7.8492796 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  7.85322145],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  7.84400288]])

# %%
skimage.io.imshow(l1_feature_map[1])
# Out:
# C:\Users\amuly\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
l1_feature_map
# Out:
# array([[[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.01261735],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 26.85677053],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 26.73178431],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  7.8492796 ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  7.85322145],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  7.84400288]],
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.46683989],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.28559145],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.1337778 ],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  8.26781172],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  8.26428957],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  8.24897346]],
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.96180179],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.75616022],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 27.57064491],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  8.69437544],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  8.69835059],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  8.66706792]],
#
#        ...,
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 14.13769789],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 14.92864684],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 15.77131704],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 33.17046701],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 33.18073098],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 33.17436191]],
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 14.70857487],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 15.46150886],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 16.1665494 ],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 32.9401237 ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 32.91130893],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 32.88525161]],
#
#        [[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 15.49347334],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 15.99045201],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 16.42262215],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 32.52360722],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 32.45293478],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        , 32.41027343]]])
